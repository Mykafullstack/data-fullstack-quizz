# %%
class Quiz():
    def __init__(self):
        pass

quiz = Quiz()

print("welcome to our quizz !")
print("you have 3 lives")

answer_1="Potter"
answer_2= "Ron"
answer_3= "Voldemort"
cpt_1=0

question_1 = input("What is Harry's family name ?")

print("1st question : What is Harry's family name ?")

print("your answer is :",question_1)

while question_1!=answer_1 and cpt_1 <= 3:

    if cpt_1==0: # sous-boucle dans la boucle while
        cpt_1+= 1           
        print("You've got two chances left.")
    elif cpt_1==1:
        cpt_1 += 1
        print("You've got only one chance left.")
    elif cpt_1==2:
        cpt_1 += 1 
        print("You've lost the game")
        break # arrête mon while dans la sous-boucle elif cpt
    
    question_1 = input("What is Harry's family name ?")

    print("1st question : What is Harry's family name ?")

    print("your answer is :",question_1)
    
else :
    print("This is the right answer.")


question_2= input("Who is Harry Potter's best friend ?")

print("2nd question :Who is Harry Potter's best friend ?")

print("your answer is :",question_2)


while question_2!=answer_2 and cpt_1 <= 3:    

    if cpt_1==0: # sous-boucle dans la boucle while
        cpt_1+= 1         
        print("You've got two chances left.")
    elif cpt_1==1:
        cpt_1 += 1  
        print("You've got only one chance left.")
    elif cpt_1==2:
        cpt_1 += 1 
        print("You've lost the game")
        break # arrête mon while dans la sous-boucle elif cpt ==2

    question_2= input("Who is Harry Potter's best friend ?")

    print("2nd question :Who is Harry Potter's best friend ?")

    print("your answer is :",question_2)

else :
    print("This is the right answer.") 


question_3=input("Who is Harry Potter's ennemy?")

print("lasy question : Who is Harry Potter's ennemy?")

print("your answer is :",question_3)

while question_3!=answer_3 and cpt_1 <= 3:    

    if cpt_1==0: # sous-boucle dans la boucle while
        cpt_1+= 1      
        print("You've got two chances left.")
    elif cpt_1==1:
        cpt_1 += 1 
        print("You've got only one chance left.")
    elif cpt_1==2:
        cpt_1 += 1  
        print("You've lost the game")
        break # arrête mon while dans la sous-boucle elif cpt ==2

    question_3= input("Who is Harry Potter's best friend ?")

    print("lasy question : Who is Harry Potter's ennemy?")

    print("your answer is :",question_3)

else :
    print("This is the right answer.")  
    print("You've won the game !!")
# Out:
# welcome to our quizz !
# you have 3 lives
# 1st question What is Harry's family name ?
# your answer is :
# You've got two chances left.
# 1st question What is Harry's family name ?
# your answer is : Potter
# This is the right answer.
# 2nd question :Who is Harry Potter's best friend ?
# your answer is : Hermione
# You've got only one chance left.
# 2nd question :Who is Harry Potter's best friend ?
# your answer is : Ron
# This is the right answer.
# lasy question : Who is Harry Potter's ennemy?
# your answer is : Draco
# You've lost the game
